# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.2/663.2 kB 4.0 MB/s eta 0:00:00

# %%
from ultralytics import YOLO

# %%
model=YOLO("yolov8m.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 191MB/s]

# %%
model.train(data='/content/gdrive/MyDrive/data_sets/Dataset/config.yaml',epochs=50)

# %%
infer=YOLO('/content/gdrive/MyDrive/data_sets/Dataset/runs/detect/train2/weights/best.pt')

# %%
# !yolo detect predict model='/content/gdrive/MyDrive/data_sets/Dataset/runs/detect/train2/weights/best.pt' source='/content/gdrive/MyDrive/data_sets/Dataset/cheetah.mp4' #using CLE

# %%
r=infer.predict('/content/gdrive/MyDrive/data_sets/Dataset/animal_video_test.mp4',save=True) #using python for video
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# video 1/1 (1/1222) /content/gdrive/MyDrive/data_sets/Dataset/animal_video_test.mp4: 384x640 1 Hyena, 211.7ms
# video 1/1 (2/1222) /content/gdrive/MyDrive/data_sets/Dataset/animal_video_test.mp4: 384x640 1 Hyena, 25.2ms
# video 1/1 (3/1222) /content/gdrive/MyDrive/data_sets/Dataset/animal_video_test.mp4: 384x640 1 Hyena, 25.1ms
# ...

# %%
r=infer.predict('/content/gdrive/MyDrive/data_sets/Dataset/animal_video_test.mp4',save=True,stream=True) #using python for video

# %%
mainlist=[]
class_label=[]
for rx in r:
  class_label=rx.verbose().split(',')
  mainlist.extend(class_label)
print(mainlist)
# Out:
# video 1/1 (1/1222) /content/gdrive/MyDrive/data_sets/Dataset/animal_video_test.mp4: 384x640 1 Hyena, 34.6ms
# video 1/1 (2/1222) /content/gdrive/MyDrive/data_sets/Dataset/animal_video_test.mp4: 384x640 1 Hyena, 25.2ms
# video 1/1 (3/1222) /content/gdrive/MyDrive/data_sets/Dataset/animal_video_test.mp4: 384x640 1 Hyena, 26.8ms
# video 1/1 (4/1222) /content/gdrive/MyDrive/data_sets/Dataset/animal_video_test.mp4: 384x640 1 Hyena, 25.4ms
# video 1/1 (5/1222) /content/gdrive/MyDrive/data_sets/Dataset/animal_video_test.mp4: 384x640 1 Hyena, 25.8ms
# video 1/1 (6/1222) /content/gdrive/MyDrive/data_sets/Dataset/animal_video_test.mp4: 384x640 1 Hyena, 25.2ms
# video 1/1 (7/1222) /content/gdrive/MyDrive/data_sets/Dataset/animal_video_test.mp4: 384x640 1 Hyena, 25.3ms
# video 1/1 (8/1222) /content/gdrive/MyDrive/data_sets/Dataset/animal_video_test.mp4: 384x640 1 Hyena, 25.2ms
# video 1/1 (9/1222) /content/gdrive/MyDrive/data_sets/Dataset/animal_video_test.mp4: 384x640 1 Hyena, 26.6ms
# ...

# %%
new_main=set(mainlist)
new_main=list(new_main)
print(new_main)
# Out:
# ['2 Foxs', '1 Hyena', ' 1 Wolf', '5 Lions', '3 Cheetahs', '3 Lions', '2 Wolfs', '3 Foxs', '1 Fox', ' 2 Hyenas', '1 Wolf', '4 Hyenas', '2 Tigers', '2 Lions', '1 Lion', '3 Wolfs', '1 Cheetah', ' 1 Lion', '2 Cheetahs', ' 1 Tiger', '4 Cheetahs', '(no detections)', ' 1 Hyena', '4 Lions', '2 Hyenas', ' ', '1 Tiger', ' 2 Wolfs', ' 4 Wolfs']

# %%
r1=infer('/content/gdrive/MyDrive/data_sets/Dataset/testing.mp4',save=True,stream=True)

# %%
res=infer.predict('/content/gdrive/MyDrive/data_sets/Dataset/LION_HYENA.jpg') #python image
# Out:
# image 1/1 /content/gdrive/MyDrive/data_sets/Dataset/LION_HYENA.jpg: 448x640 1 Cheetah, 1 Lion, 1524.7ms
# Speed: 3.5ms preprocess, 1524.7ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
# 674 labels saved to runs/detect/predict/labels

# %%
# !ffmpeg -i {"/content/runs/detect/predict/animal_video_test.avi"} -vcodec libx264 {"animal_video_output.mp4"} #to compress the video and name it output
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
#Saving the data
# !scp -r /content/runs '/content/gdrive/My Drive/data_sets/Dataset'
